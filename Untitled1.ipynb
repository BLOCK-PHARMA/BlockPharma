# %%
# !ls
# Out:
# README.md
# Untitled1.ipynb
# build
# contracts
# favicon.ico
# migrations
# package.json
# test
# truffle-config.js
# web

# %%
# %%timeit -n 1 -r 10
# !truffle test
# Out:
# Using network 'development'.
#
#
# Compiling your contracts...
# ...
# > Everything is up to date, there is nothing to compile.
#
#
#
#   Contract: ProductManagement
#     âˆš should create a wheel and store it (523ms)
#     âˆš should create a car using 3 parts and store it (1572ms)
#
#   Contract: ChangeOwnership
#     âˆš should be able to assign ownership to manufacturer when part does not have owner (574ms)
#     âˆš should be able to change ownership when owner requests (921ms)
#
#
#   4 passing (6s)
#
# Using network 'development'.
#
#
# Compiling your contracts...
# ...
# > Everything is up to date, there is nothing to compile.
#
#
#
#   Contract: ProductManagement
#     âˆš should create a wheel and store it (595ms)
#     âˆš should create a car using 3 parts and store it (3158ms)
#
#   Contract: ChangeOwnership
#     âˆš should be able to assign ownership to manufacturer when part does not have owner (1149ms)
#     âˆš should be able to change ownership when owner requests (1362ms)
#
# ...
